# %% [markdown]
# ### Se på interndokumentasjon til alle innstallerte packages

# %%
import subprocess
import json
import ipywidgets as widgets
from importlib.metadata import version, metadata, requires

# %% [markdown]
# ### Skaff en liste med innstallerte packagenavn

# %%
data = subprocess.check_output(["pip", "list", "--format", "json"])
parsed_results = json.loads(data)
pk_list = [(element["name"]) for element in parsed_results]

# %% [markdown]
# ### Skriv notater her etter hvert som du utforsker pakkene

# %%
# Skriv notater her når du har lest om en pakke.
# Om en rad begynner med mellomrom, så vil linjen ignoreres.
# Noter gjerne for hver runde du gjør, med dato først, eller fjern datoen og legg inn i alfabetisk rekkefølge

notater = """
 - 2020-10-20
aiohttp         - async http client/server for asyncio
alembic         - database migration for sqlalchemy
ansiwrap        - wraps text, including ansi-control sequences, that stylizes or colors text
appdirs         - Utilities for determining application-specific dirs.
async-generator - implements async generators in Python 3.5 (necessary in newer versions?)
async-timeout   - asyncio-compatible timeout context manager.
attrs           - Interesting... Helps avoid implementing dunder methods. Aides in type-annotation
backcall        - Specifications for callback functions passed in to an API. Create prototypes for expected callback signature.
backports.functools-lru-cache - Decorator to wrap a function with a memoizing callable that saves up to the maxsize most recent calls. It can save time when an expensive or I/O bound function is periodically called with the same arguments.
beautifulsoup4  - Beautiful Soup is a library that makes it easy to scrape information from web pages. It sits atop an HTML or XML parser, providing Pythonic idioms for iterating, searching, and modifying the parse tree.
black           - code style enforcer / formatter
bleach          - Clean an HTML fragment of malicious content and return it
blinker         - Blinker provides fast & simple object-to-object and broadcast signaling for Python objects.
bokeh           - Bokeh is a Python interactive visualization library that targets modern web browsers for presentation.
Bottleneck      - Bottleneck is a collection of fast NumPy array functions written in C.
brotlipy        - allows use of the Brotli compression algorithm directly from Python code. Brotli is a generic-purpose lossless compression algorithm that compresses data using a combination of a modern variant of the LZ77 algorithm, Huffman coding and 2nd order context modeling, with a compression ratio comparable to the best currently available general-purpose compression methods.
cachetools      - Extensible memoizing collections and decorators.
certifi         - provides Mozilla’s carefully curated collection of Root Certificates for validating the trustworthiness of SSL certificates while verifying the identity of TLS hosts. It has been extracted from the Requests project.
certipy         - A simple python tool for creating certificate authorities and certificates on the fly.
cffi            - C Foreign Function Interface for Python. Interact with almost any C code from Python, based on C-like declarations that you can often copy-paste from header files or documentation.
chardet         - Character encoding auto-detection in Python.
click           - inspired by the stdlib optparse to make writing command line scripts fun. It’s the “Command Line Interface Creation Kit”.
cloudpickle     - makes it possible to serialize Python constructs not supported by the default pickle module from the Python standard library.
colorama        - Makes ANSI escape character sequences (for producing colored terminal text and cursor positioning) work under MS Windows.
conda           - OS-agnostic, system-level binary package manager.
conda-package-handling
cryptography    - provides cryptographic recipes and primitives to Python developers
cycler          - Cycling through combinations of values, producing dictionaries.
Cython          - an optimising static compiler for both the Python programming language and the extended Cython programming language. It makes writing C extensions for Python as easy as Python itself.
cytoolz         - Cython implementation of the toolz package, which provides high performance utility functions for iterables, functions, and dictionaries.
dask            - provides advanced parallelism for analytics, enabling performance at scale for the tools you love
decorator       - make it easy to define signature-preserving function decorators and decorator factories. 
defusedxml      - Defuse XML bomb denial of service vulnerabilities
dill            - extends python's ``pickle`` module for serializing and de-serializing python objects to the majority of the built-in python types.
distributed     - distributed task scheduling for dask?
entrypoints     - Discover and load entry points from installed packages.
fastcache       - C implementation of LRU caching.
findspark       - If SPARK_HOME is defined, it will be used to put pyspark on sys.path. Otherwise, common locations for spark (currently only Homebrew's default) will be searched.
fsspec          - work with remote filesystems and file-system-like abstractions using a standard pythonic interface. FTP, Google drive, dropbox, azure, dask, samba, git
gcsfs           - Connect to Google Cloud Storage
gitdb           - git object database module
GitPython       - interact with git repositories, high-level like git-porcelain, or low-level like git-plumbing.
gmpy2           - C-coded Python extension module that supports multiple-precision arithmetic.
google-auth     -  This library provides the ability to authenticate to Google APIs using various methods. It also provides integration with several HTTP libraries.
google-auth-oauthlib - provides oauthlib integration with google-auth
h5py            - This is the h5py package, a Python interface to the HDF5 scientific data format.
HeapDict        - Compared to an ordinary dict, a heapdict has the following differences: popitem(): Remove and return the (key, priority) pair with the lowest priority, instead of a random object.  peekitem():Return the (key, priority) pair with the lowest priority, without removing it.Unlike the Python standard library’s heapq module, the heapdict supports efficiently changing the priority of an existing object (often called “decrease-key” in textbooks). Altering the priority is important for many algorithms such as Dijkstra’s Algorithm and A*.
idna            - Support for the Internationalised Domain Names in Applications (IDNA) protocol as specified in RFC 5891.
imagecodecs     - provides block-oriented, in-memory buffer transformation, compression, and decompression functions for use in the tifffile, czifile, and other scientific image input/output modules.
imageio         - Imageio is a Python library that provides an easy interface to read and write a wide range of image data, including animated images, volumetric data, and scientific formats.
importlib-metadata - access the metadata for a Python package. It is intended to be ported to Python 3.8.
iniconfig       - Parser for ini-style files.
ipykernel       - The IPython kernel for Jupyter
ipympl          - Matplotlib Jupyter Extension
ipyparallel     - The IPython ZMQ-based parallel computing interface
ipython         - Runs the notebook server? a command shell for interactive computing in multiple programming languages, originally developed for the Python programming language, that offers introspection, rich media, shell syntax, tab completion, and history.
ipython-genutils - This package shouldn't exist.
ipywidgets      - Interactive widgets for the Jupyter notebook.
jedi            - static analysis tool for Python that is typically used in IDEs/editors plugins. Jedi has a focus on autocompletion and goto functionality. Other features include refactoring, code search and finding references.
Jinja2          - Templating language for Python, modelled after Django’s templates.
joblib          - set of tools to provide **lightweight pipelining in Python**.
json5           - implementation of the JSON5 configuration language. JSON5 extends the JSON data interchange format to make it slightly more usable as a configuration language
jsonschema      - implementation of JSON Schema
jupyter-client  - contains the reference implementation of the Jupyter protocol. It also provides client and kernel management APIs for working with kernels.
jupyter-core    - There is no reason to install this package on its own.
jupyter-server-proxy - lets you run arbitrary external processes (such as RStudio, Shiny Server, Syncthing, PostgreSQL, Code Server, etc) alongside your notebook server and provide authenticated web access to them using a path like /rstudio next to others like /lab. 
jupyter-telemetry - enables Jupyter Applications to record events—i.e. actions by application users—and transmit them to remote (or local) destinations as structured data. It works with Python's standard logging library to handle the transmission of events allowing users to send events to local files, over the web, etc.
jupyterhub      - the best way to serve Jupyter notebook for multiple users. It can be used in a classes of students, a corporate data science group or scientific research group. It is a multi-user Hub that spawns, manages, and proxies multiple instances of the single-user Jupyter notebook server.
jupyterlab      - Server extension for JupyterLab.
jupyterlab-git  - JupyterLab extension for version control using Git
jupyterlab-server - set of server components for JupyterLab and JupyterLab like applications
kiwisolver      - Cassowary constraint solving algorithm. 
koalas          - implementing the pandas DataFrame API on top of Apache Spark
llvmlite        - lightweight LLVM python binding for writing JIT compilers. + Numba - translates Python functions to optimized machine code at runtime using the industry-standard LLVM compiler library.
locket          - a lock that can be used by multiple processes provided they use the same path. In case you dont want several processes to work on the same file at the same time.
lxml            - processing XML and HTML
Mako            - template library. It provides a familiar, non-XML syntax which compiles into Python modules for maximum performance. 
MarkupSafe      - implements a text object that escapes characters so it is safe to use in HTML and XML
matplotlib      - This is an object-oriented plotting library.
metakernel      - Jupyter kernel base class in Python which includes core magic functions
mistune         - The fastest markdown parser in pure Python with renderer feature.
mock            - for testing in Python. It allows you to replace parts of your system under test with mock objects and make assertions about how they have been used.
mpmath          - real and complex floating-point arithmetic with arbitrary precision.
msgpack         - efficient binary serialization format. It lets you exchange data among multiple languages like JSON.
multidict       - HTTP Headers and URL query string require specific data structure: multidict. It behaves mostly like a dict but it can have several values for the same key.
mypy-extensions - experimental extensions to the standard “typing” module that are supported by the mypy typechecker.
nbclient        - programmatic notebook execution, is a tool for running Jupyter Notebooks in different execution contexts.
nbconvert       - Utilities for converting notebooks to and from different formats.
nbdime          - provides tools for diffing and merging of Jupyter Notebooks.
nbformat        - The Jupyter notebook format
nbstripout      - Opens a notebook, strips its output, and writes the outputless version to the original file. Useful mainly as a git filter or pre-commit hook for users who don't want to track output in VCS
nest-asyncio    - patches asyncio to allow nested use of asyncio.run and loop.run_until_complete. The issue pops up in various environments, such as web servers, GUI applications and in Jupyter notebooks.
networkx        - creation, manipulation, and study of the structure, dynamics, and functions of complex networks.
notebook        - The Jupyter HTML Notebook
numba           - Numba translates Python functions to optimized machine code at runtime using the industry-standard LLVM compiler library. Numba-compiled numerical algorithms in Python can approach the speeds of C or FORTRAN.
numexpr         - fast numerical expression evaluator for NumPy.  With it, expressions that operate on arrays (like "3*a+4*b") are accelerated and use less memory than doing the same calculation in Python.
numpy           - provides fast mathematical computation on arrays and matrices.
oauthlib        - generic, spec-compliant, thorough implementation of the OAuth request-signing logic.
olefile         - read/write Microsoft OLE2 files, such as Microsoft Office 97-2003 documents, Image Composer and FlashPix files, Outlook messages
packaging       - Core utilities for Python packages. The packaging project includes the following: version handling, specifiers, markers, requirements, tags, utilities.
pamela          - Provides an authenticate function that will allow the caller to authenticate a user against the Pluggable Authentication Modules (PAM) on the system.
pandas          - a powerful data analysis and manipulation library for Python
pandocfilters   - Functions to aid writing python scripts that process the pandoc AST serialized as JSON.
papermill       - parameterizing and executing Jupyter Notebooks.
parso           - parser that supports error recovery and round-trip parsing for different Python versions (in multiple Python versions). Parso is also able to list multiple syntax errors in your python file.
partd           - Key-value byte store with appendable values. Partd excels at shuffling operations.
pathspec        - provides pattern matching for file paths. So far this only includes Git's wildmatch pattern matching (the style used for  ".gitignore" files).
patsy           - describing statistical models and building design matrices. It is closely inspired by the 'formula' mini-language used in R and S.
pexpect         - spawning child applications and controlling them automatically. Pexpect can be used for automating interactive applications such as ssh, ftp, passwd, telnet, etc
pickleshare     - small 'shelve' like datastore with concurrency support
Pillow          - Python Imaging Library adds image processing capabilities to your Python interpreter. This library provides extensive file format support, an efficient internal representation, and fairly powerful image processing capabilities.
pip             - the package installer for Python. You can use pip to install packages from the Python Package Index and other indexes.
pluggy          - A minimalist production ready plugin system
portalocker     - provide an easy API to file locking.
prometheus-client - Implementation of prometheus, instrumenting and monitoring applications.
prompt-toolkit  - building powerful interactive command line applications in Python.
protobuf        - Protocol Buffers are Google’s data interchange format
psutil          - cross-platform library for retrieving information on running processes and system utilization (CPU, memory, disks, network, sensors) in Python.
ptyprocess      - Run a subprocess in a pseudo terminal
py              - pylib: rapid testing and development utils - this module uses apipkg.py for lazy-loading sub modules and classes.
pyarrow         - implementation of Apache Arrow.
pyasn1          - ASN.1 types and DER/BER/CER codecs (X.208) ASN.1 solves the data serialisation problem. That probably explains why many network protocols and file formats still rely on the 30+ years old technology. Including a number of high-profile Internet protocols and file formats.
pyasn1-modules  - collection of ASN.1 modules expressed in form of pyasn1 classes. Includes protocols PDUs definition (SNMP, LDAP etc.) and various data structures (X.509, PKCS etc.).
pycosat         - bindings to PicoSAT - determine if set of logical conditions is satisfiable
pycparser       - complete parser of the C language
pycurl          - This module implements an interface to the cURL library.
Pygments        - generic syntax highlighter suitable for use in code hosting, forums, wikis or other applications that need to prettify source code.
pyjstat         - for JSON-stat formatted data manipulation which allows reading and writing JSON-stat format with python, using the DataFrame structures provided by the widely accepted pandas library. 
PyJWT           - allows you to encode and decode JSON Web Tokens (JWT).
pyOpenSSL       - If you are using pyOpenSSL for anything other than making a TLS connection you should move to cryptography and drop your pyOpenSSL dependency.
pyparsing       - Classes and methods to define and execute parsing grammars
pyrsistent      - Persistent/Functional/Immutable data structures
PySocks         - lets you send traffic through SOCKS and HTTP proxy servers.
pytest          - unit and functional testing with Python.
python-dateutil - powerful extensions to the standard datetime module
python-editor   - provides the editor module for programmatically interfacing with your system’s $EDITOR.
python-json-logger - allow standard python logging to output log data as json objects. With JSON we can make our logs more readable by machines and we can stop writing custom parsers for syslog type records.
pytz            - datetime.tzinfo timezone definitions generated from the Olson timezone database
PyWavelets      - wavelet transforms module
PyYAML          - YAML is a data serialization format designed for human readability and interaction with scripting languages. PyYAML is a YAML parser and emitter for Python.
pyzmq           - Python bindings for ØMQ - Universal messaging library
regex           - Support for regular expressions (RE).
requests        - HTTP library, for human beings.
requests-oauthlib - OAuth library support for Requests
rsa             - for calculating large primes, and RSA encryption, decryption, signing and verification. Includes generating public and private keys.
ruamel-yaml     - 
ruamel.yaml     - YAML 1.2 loader/dumper
ruamel.yaml.clib - C based reader/scanner and emitter for ruamel.yaml
scikit-image    - image processing library. It includes algorithms for segmentation, geometric transformations, color space manipulation, analysis, filtering, morphology, feature detection, and more.
scikit-learn    - machine learning. It features various classification, regression and clustering algorithms including support vector machines
scipy           - scientific computing and technical computing. SciPy contains modules for optimization, linear algebra, integration, interpolation, special functions, FFT, signal and image processing, ODE solvers and other tasks common in science and engineering
seaborn         - Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
Send2Trash      - sends files to the Trash (or Recycle Bin) natively and on all platforms.
setuptools      - Extensions to the 'distutils' for large or complex distributions. Make packages.
simpervisor     - Simple async process supervisor
six             - Utilities for writing code that runs on Python 2 and 3
smmap           - Although memory maps have many advantages, they represent a very limited system resource as every map uses one file descriptor, whose amount is limited per process. Smmap wraps an interface around mmap and tracks the mapped files as well as the amount of clients who use it. If the system runs out of resources, or if a memory limit is reached, it will automatically unload unused maps to allow continued operation.
sortedcontainers - Sorted List, Sorted Dict, Sorted Set - Sorted Containers is an Apache2 licensed containers library, written in pure-Python, and fast as C-extensions
soupsieve       -  A CSS selector filter for BeautifulSoup4.
spylon          - set of compatibility routines for making it easier to interact with Scala from Python.
spylon-kernel   - A Scala Jupyter kernel
SQLAlchemy      - SQL toolkit and Object Relational Mapper that gives application developers the full power and flexibility of SQL.
ssb-ipython-kernels - kernel extensions for integrating with Apache Spark, Google Cloud Storage and custom dapla services.
ssb-spark-tools -  colection of Data processing functions for the use in Data processing in Statistics Norway
statsmodels     - provides classes and functions for the estimation of many different statistical models, as well as for conducting statistical tests, and statistical data exploration.
sympy           - symbolic mathematics. It aims to become a full-featured computer algebra system (CAS) while keeping the code as simple as possible in order to be comprehensible and easily extensible.
tables          - PyTables, hierarchical datasets in Python.
tblib           - Serialization library for Exceptions and Tracebacks.
tenacity        - general-purpose retrying library, to simplify the task of adding retry behavior to just about anything.
terminado       - Terminals served to xterm.js using Tornado websockets
testpath        - Test utilities for code working with files and commands
textwrap3       - Text wrapping and filling.
threadpoolctl   - This module provides utilities to introspect native libraries that relies on thread pools (notably BLAS and OpenMP implementations) and dynamically set the maximal number of threads they can use.
tifffile        - Read and write TIFF(r) files.tifffile - Read and write TIFF(r) files.
toml            - parses and emits TOML. (Comparable to YAML?)
toolz           - A set of utility functions for iterators, functions, and dictionaries.
tornado         - The Tornado web server and tools.
tqdm            - progressbar
traitlets       - lets classes have attributes with type checking, dynamically calculated default values, and ‘on change’ callbacks.
typed-ast       - similar to the standard ast library. Unlike ast, the parsers in typed_ast include PEP 484 type comments and are independent of the version of Python under which they are run. The ast module helps Python applications to process trees of the Python abstract syntax grammar. 
typing-extensions - Backported and Experimental Type Hints for Python
urllib3         - Thread-safe connection pooling and re-using. urllib3 is a powerful, sanity-friendly HTTP client for Python. Much of the Python ecosystem already uses urllib3 and you should too.
vincent         - The folks at Trifacta are making it easy to build visualizations on top of D3 with Vega. Vincent makes it easy to build Vega with Pytho
wcwidth         - for CLI programs that carefully produce output for Terminals, or make pretend to be an emulator.
webencodings    - implementation of the `WHATWG Encoding standard'
wheel           - implementation of the wheel packaging standard, as defined in PEP 427.
widgetsnbextension - Interactive widgets for the Jupyter notebook. Uses ipywidget from ipython
xlrd            - Extract data from Excel spreadsheets (.xls and .xlsx) on any platform.
xmltodict       - Makes working with XML feel like you are working with JSON
yarl            - provides handy URL class for URL parsing and changing.
zict            - Composable Mutable Mappings. The dictionary / mutable mapping interface is powerful and multi-faceted.
zipp            - A pathlib-compatible Zipfile object wrapper. A backport of the Path object.
"""

# %% [markdown]
# ### Tips til enkle og raske tutorials
# - ipywidget, widgetsnbextension
# - tqdm
#
#
# ### Interessante tema utifra innstallerte pakker
#
#
# 1. Bottleneck, gmpy2, h5py, kiwisolver, networkx, numexpr, patsy, pyarrow, picosat, pyjstat, PyWavelets, scikit-image, scikit-learn, scipy, seaborn, statsmodels, sympy, tables, vincent - grafikk, statistikk-matte, moving mean, benchmark
# 1. dask + distributed - Data science analytics
# 1. logging, jupyter-telemetry, python-json-logger, tblib - logging
# 1. cachetools + backports.functools-lru-cache + fastcache + joblib: fast data science-code, "memoizing"
# 1. typing-extensions, attrs, mypy-extensions, traitlets - type hints / annotations / typing
# 1. Django, Jinja2, Mako, Mistune, Pygments, PyJWT, webencodings, yarl - templating and web-formatting
# 1. Jupyter-telemetry, blinker, nbclient, nbconvert, papermill, pexpect, ptyprocess, pyzmq, tenacity - sending signals, excecuting in different contexts?
# 1. jupyterhub, nbdime, hvordan jobbe oppå hverandre? Brukes dette allerede?
#
#
#
# - beautifulsoup, lxml, pyparsing, soupsieve, textwrap3 = webscraping / parsing content
# - cffi, cython, cytools, pycparser = excecuting c-code from python
# - click, prompt_toolkit = “Command Line Interface Creation Kit” - Mulig i Jupyter? Sammen med "%%python"?
# - cycler, toolz: check use cases
# - HeapDict, multidict, sortedcontainers, typed-ast, zict: use-cases
# - Ipython: how does it relate to jupyter?
# - Jedi: hvordan er det implementert i jupyter?
# - Mock, pluggy, prometheus-client, py, pytest, testpath  = unittests (+ Tox?)

# %% [markdown]
# ### Filtrer vekk de som allerede har notater

# %%
notat_list = notater.splitlines()
notat_list_cl = []
for linje in notat_list:
    if linje:
        notat_list_cl.append(linje.split(" ", 1)[0])

#pk_list_filter = [x for x in pk_list if (x not in notat_list_cl)]
# Bytt om utkommentering, om du vil fjerne/vise de pakkene som det er notater på.
pk_list_filter = pk_list

# %% [markdown]
# ### Lag en dropdown-meny av packages du ikke har kommentert på enda

# %%
# Definer dropdown
pk = widgets.Dropdown(
    options= pk_list_filter,
    description='Se på:',
    value=pk_list_filter[0],
    disabled=False,
)

def combo_out(pack):
    # Annen interessant info om pakken
    # Version
    print(f"Version: {version(pack)}")
    # Requirements
    req = requires(pack)
    if req:
        print('-'*55)
        print(f"Requires:")
        for x in req: print(x.split(';',1)[0])
    print('-'*55 + "\n")
    
    # Display ny hjelp-docs for den valgte dropdown-valget
    help(pack)
    

# Definer intiell output-område
out = widgets.Output(layout={'border': '1px solid white'})
with out:
    display(pk)
    combo_out(pk_list_filter[0])
    
# Decorator for å ta oppdatert output
@out.capture()
def on_value_change(change):
    # Om vi ikke clearer output, så vil neste docs komme under forrige
    out.clear_output()
    # Om vi ikke displayer denne igjen, vil den bli borte
    display(pk)
    # combined output function
    combo_out(change['new'])

# Call funksjonen over når endringer gjøres til dropdownen
pk.observe(on_value_change, names='value')

# Display outputen
display(out)
